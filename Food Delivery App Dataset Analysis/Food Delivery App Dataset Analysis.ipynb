# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Importing the Dataset

# %%
data = pd.read_csv("C:\\Users\\hp\\Desktop\\Datasets\\Food_delivery.csv")
data
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# #### Showing first 5 rows & columns and last 5 rows & columns

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
data.tail()
# Out:
#                  name online_order book_table   rate  votes  \
# 143  Melting Melodies           No         No  3.3/5      0
# 144   New Indraprasta           No         No  3.3/5      0
# 145      Anna Kuteera          Yes         No  4.0/5    771
# 146            Darbar           No         No  3.0/5     98
# 147     Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 143                          100          Dining
# 144                          150          Dining
# 145                          450          Dining
# 146                          800          Dining
# 147                          200          Dining

# %% [markdown]
# #### Shape of dataset i.e number of rows and number of columns

# %%
print("Number of rows = ",data.shape[0])
print("Number of columns = ",data.shape[1])
# Out:
# Number of rows =  148
# Number of columns =  7

# %% [markdown]
# #### Showing information about dataset like count , dtype, memory usage , entries

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %% [markdown]
# #### Describe of the dataset like unique values , max , min , 25% ,50% , top etc

# %%
data.describe(include = 'all')
# Out:
#                    name online_order book_table   rate        votes  \
# count               148          148        148    148   148.000000
# unique              145            2          2     20          NaN
# top     San Churro Cafe           No         No  3.8/5          NaN
# freq                  2           90        140     19          NaN
# mean                NaN          NaN        NaN    NaN   264.810811
# std                 NaN          NaN        NaN    NaN   653.676951
# min                 NaN          NaN        NaN    NaN     0.000000
# 25%                 NaN          NaN        NaN    NaN     6.750000
# 50%                 NaN          NaN        NaN    NaN    43.500000
# 75%                 NaN          NaN        NaN    NaN   221.750000
# max                 NaN          NaN        NaN    NaN  4884.000000
#
#         approx_cost(for two people) listed_in(type)
# count                    148.000000             148
# ...

# %% [markdown]
# #### Check datasets have null values or not

# %%
data.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %% [markdown]
# #### Check whether dataset have any duplicate value or not

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Checking how many restaurents are categorized into different listed_in(type)

# %%
data[data['listed_in(type)'] == 'Dining'].count()
# Out:
# name                           110
# online_order                   110
# book_table                     110
# rate                           110
# votes                          110
# approx_cost(for two people)    110
# listed_in(type)                110
# dtype: int64

# %%
a = sns.countplot(x = "listed_in(type)",data = data,hue = "listed_in(type)")
for x in a.containers:
    a.bar_label(x)

# %% [markdown]
# ##### Conclusion: The majority of the restaurants fall into the dining category.

# %% [markdown]
# #### People prefer which type of listed_in(type)

# %%
grouped_data = data.groupby('listed_in(type)')['votes'].sum()
result = pd.DataFrame({'votes':grouped_data})

# %%
plt.plot(result,c='orange')
plt.show()

# %% [markdown]
# ##### Conclusion: Dining restaurants are preferred by a larger number of individuals.

# %% [markdown]
# #### Restaurents with maximum votes

# %%
data.groupby('name')['votes'].max().sort_values(ascending = False).head(1)
# Out:
# name
# Empire Restaurant    4884
# Name: votes, dtype: int64

# %% [markdown]
# #### How many ordered online or offline

# %%
z = sns.countplot(x = 'online_order',data = data,hue = 'online_order')
for x in z.containers:
    z.bar_label(x)

# %% [markdown]
# ##### Conclusion: This suggests that a majority of the restaurants do not accept online orders.

# %% [markdown]
# #### People provided which ratings the most

# %%
r = sns.histplot(x = 'rate',data = data,hue = 'rate',legend = False)
for x in r.containers:
    r.bar_label(x)
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ##### Conclusion: The majority of restaurants received ratings ranging from 3.5 to 4.

# %% [markdown]
# #### How many couples spended average money on meals

# %%
v = sns.countplot(x = 'approx_cost(for two people)' , data = data,hue = 'approx_cost(for two people)',legend = False)
plt.xticks(rotation = 40)
for x in v.containers:
    v.bar_label(x)
plt.show()

# %% [markdown]
# ##### Conclusion: The majority of couples prefer restaurants with an approximate cost of 300 rupees.

# %% [markdown]
# #### Which order online or offline received maximum voting

# %%
plt.figure(figsize = (6,6))
sns.boxplot(x = 'online_order',y = 'rate',data = data,hue = 'online_order')
plt.show()

# %% [markdown]
# ##### Conclusion:Offline order received less ratings than online order

# %%
pivot_table = data.pivot_table(index = 'listed_in(type)',columns = 'online_order',aggfunc = 'size',fill_value = 0)
sns.heatmap(pivot_table,annot = True,cmap = 'YlGnBu',fmt = 'd')
plt.title('Heatmap')
plt.xlabel('Online order')
plt.ylabel('Listed In (Type)')
plt.show()

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# #### Finding out the average cost per listed_in(type)

# %%
s = sns.barplot(x = 'listed_in(type)' , y = 'approx_cost(for two people)', data = data,errorbar = None,hue = 'listed_in(type)')
for x in s.containers:
    s.bar_label(x)

# %% [markdown]
# #### How much money is earned by dining , cafes , other and buffet

# %%
w = data.groupby('listed_in(type)')['approx_cost(for two people)'].sum().sort_values(ascending = False)
w
# Out:
# listed_in(type)
# Dining    39300
# Cafes     12550
# other      5350
# Buffet     4700
# Name: approx_cost(for two people), dtype: int64

# %%
q = sns.barplot(w,palette = 'gist_rainbow')
for x in q.containers:
    q.bar_label(x)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_816\1537879099.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   q = sns.barplot(w,palette = 'gist_rainbow')

# %% [markdown]
# ##### Conclusion : We made the conclusion that dining had huge earnings followed by Cafes , other and Buffet had least earnings

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# #### Who got the highest number of votes

# %%
data.groupby('name')['votes'].max().sort_values(ascending = False).head()
# Out:
# name
# Empire Restaurant    4884
# Meghana Foods        4401
# Onesta               2556
# Kabab Magic          1720
# Szechuan Dragon      1647
# Name: votes, dtype: int64

# %% [markdown]
# ##### Conclusion : Empire Restaurant got highest number of votes

# %% [markdown]
# #### Sum of revenue per Hotel name

# %%
data['name'].unique()
# Out:
# array(['Jalsa', 'Spice Elephant', 'San Churro Cafe',
#        'Addhuri Udupi Bhojana', 'Grand Village', 'Timepass Dinner',
#        'Rosewood International Hotel - Bar & Restaurant', 'Onesta',
#        'Penthouse Cafe', 'Smacznego', 'Village Café', 'Cafe Shuffle',
#        'The Coffee Shack', 'Caf-Eleven', 'Cafe Vivacity', 'Catch-up-ino',
#        "Kirthi's Biryani", 'T3H Cafe', '360 Atoms Restaurant And Cafe',
#        'The Vintage Cafe', 'Woodee Pizza', 'Cafe Coffee Day',
#        'My Tea House', 'Hide Out Cafe', 'CAFE NOVA', 'Coffee Tindi',
#        'Sea Green Cafe', 'Cuppa', "Srinathji's Cafe", 'Redberrys',
#        'Foodiction', 'Sweet Truth', 'Ovenstory Pizza', 'Faasos',
#        'Behrouz Biryani', 'Fast And Fresh', 'Szechuan Dragon',
#        'Empire Restaurant', 'Maruthi Davangere Benne Dosa', 'Chaatimes',
#        'Havyaka Mess', "McDonald's", "Domino's Pizza", 'Hotboxit',
#        'Kitchen Garden', 'Recipe', 'Beijing Bites', 'Tasty Bytes',
# ...

# %%
z = data.groupby('name')['approx_cost(for two people)'].sum().sort_values(ascending = False).head(10)
z
# Out:
# name
# San Churro Cafe         1600
# CAFE NOVA               1200
# Onesta                  1200
# Ayda Persian Kitchen     950
# K27 - The Pub            900
# Cafe Coffee Day          900
# Jeet Restaurant          850
# Beijing Bites            850
# Spice Elephant           800
# Goa 0 Km                 800
# Name: approx_cost(for two people), dtype: int64

# %%
s = sns.barplot(z)
for x in s.containers:
    s.bar_label(x)
plt.xticks(rotation = 70)
plt.show()

# %% [markdown]
# ##### Conclusion: San Churro Cafe earned the highest revenue

# %%
data.sample(5)
# Out:
#                    name online_order book_table   rate  votes  \
# 87        Krishna Sagar           No         No  3.5/5     31
# 90       Me And My Cake           No         No  3.7/5      0
# 136  Sri Sai Tiffannies           No         No  3.3/5      0
# 62      Chinese Kitchen          Yes         No  3.8/5     58
# 9             Smacznego          Yes         No  4.2/5    504
#
#      approx_cost(for two people) listed_in(type)
# 87                           200          Dining
# 90                           500          Dining
# 136                          150          Dining
# 62                           150          Dining
# 9                            550           Cafes

# %% [markdown]
# #### Total earnings by online and offline orders

# %%
f = data.groupby('online_order')['approx_cost(for two people)'].sum()
f
# Out:
# online_order
# No     32300
# Yes    29600
# Name: approx_cost(for two people), dtype: int64

# %%
h = sns.barplot(f,palette='gist_rainbow')
for x in h.containers:
    h.bar_label(x)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_816\1021920567.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   h = sns.barplot(f,palette='gist_rainbow')

# %% [markdown]
# ##### Conclusion : Money made by offline orders are more than online orders.

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.scatterplot(y = 'votes',x = 'approx_cost(for two people)',data = data)
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='votes'>
