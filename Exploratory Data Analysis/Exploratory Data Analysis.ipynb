# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\hp\\Downloads\\supermarket_sales - Sheet1.csv",parse_dates = ["Date"])
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
import warnings

# %% [raw]
# warnings.filterwarnings("ignore")

# %% [markdown]
# #### Random 5 rows from our dataset

# %%
data.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 416  750-57-9686      C  Naypyitaw        Normal  Female
# 900  377-79-7592      C  Naypyitaw        Member  Female
# 998  347-56-2442      A     Yangon        Normal    Male
# 257  729-09-9681      A     Yangon        Member    Male
# 79   756-01-7507      C  Naypyitaw        Normal  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 416      Home and lifestyle       45.38         4   9.076  190.596 2019-01-08
# 900  Electronic accessories       44.84         9  20.178  423.738 2019-01-14
# 998      Home and lifestyle       65.82         1   3.291   69.111 2019-02-22
# 257      Home and lifestyle       25.91         6   7.773  163.233 2019-02-05
# 79        Health and beauty       20.38         5   5.095  106.995 2019-01-22
#
#       Time      Payment    cogs  gross margin percentage  gross income  Rating
# ...

# %% [markdown]
# #### Shape of Dataset

# %%
print("No. of rows = ",data.shape[0])
print("No. of columns = ",data.shape[1])
# Out:
# No. of rows =  1000
# No. of columns =  17

# %% [markdown]
# #### Null values

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# #### Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# #### Statistics

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date        cogs  gross margin percentage  \
# count                        1000  1000.00000             1.000000e+03
# mean   2019-02-14 00:05:45.600000   307.58738             4.761905e+00
# min           2019-01-01 00:00:00    10.17000             4.761905e+00
# 25%           2019-01-24 00:00:00   118.49750             4.761905e+00
# 50%           2019-02-13 00:00:00   241.76000             4.761905e+00
# ...

# %%
cat = []
num = []
for column in data.columns:
    if data[column].nunique() > 10:
        num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Aggregate sales among branches.

# %%
a = sns.countplot(x = "Branch",data = data,hue = "Branch")
for x in a.containers:
    a.bar_label(x)

# %%
data["Branch"].value_counts().plot(kind = "pie",autopct = "%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #### Most Popular Payment Method used by customers

# %%
data["Payment"].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
data["Payment"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Payment'>

# %% [markdown]
# #### Distribution of customer ratings

# %%
sns.distplot(data["Rating"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12264\2189940401.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Rating"])
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
data["Rating"].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# #### Distribution of cost of goods sold

# %%
sns.distplot(data["cogs"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12264\3875859950.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["cogs"])
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
data["cogs"].skew()
# Out:
# 0.8925698049581418

# %%
sns.boxplot(data["cogs"])
# Out:
# <Axes: ylabel='cogs'>

# %% [markdown]
# ### Bivariate Analysis/Multivariate Analysis

# %% [markdown]
# #### Does cost of goods sold affect the ratings that the customers provide

# %%
sns.scatterplot(x = "cogs",y = "Rating",data = data)
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %% [markdown]
# #### Does gross income affect the ratings that the customers provide

# %%
sns.scatterplot(x = "gross income",y = "Rating",data = data)
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# #### Most profitable branch as per gross income

# %%
q = sns.barplot(x = "Branch",y = "gross income",hue = "City",data = data,errorbar = None)
for x in q.containers:
    q.bar_label(x)

# %% [markdown]
# #### Relation between gender and gross income

# %%
sns.boxplot(x = "Gender",y = "gross income",hue = "Customer type",data = data)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# #### Product line that generates more income

# %%
w = sns.barplot(x = "Product line",y = "gross income",data = data,hue = "Product line",errorbar = None)
plt.xticks(rotation = 30)
for x in w.containers:
    w.bar_label(x)
plt.show()

# %% [markdown]
# #### Highest Unit price in the product line

# %%
e = sns.barplot(x = "Product line",y = "Unit price",data = data,hue = "Product line",errorbar = None)
plt.xticks(rotation = 50)
for x in e.containers:
    e.bar_label(x)
plt.show()

# %% [markdown]
# #### Different Payment Methods used by customers citywise

# %%
s = sns.countplot(x = "Payment",data = data,hue = "City")
for x in s.containers:
    s.bar_label(x)

# %%
pd.crosstab(data["City"],data["Payment"])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(data["City"],data["Payment"]))
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %% [markdown]
# #### Product line which is purchased in highest quantity

# %%
data.groupby("Product line")["Quantity"].sum().sort_values(ascending = False)
# Out:
# Product line
# Electronic accessories    971
# Food and beverages        952
# Sports and travel         920
# Home and lifestyle        911
# Fashion accessories       902
# Health and beauty         854
# Name: Quantity, dtype: int64

# %%
(data.groupby("Product line")["Quantity"].sum().sort_values(ascending = False)).plot(kind = "bar")
# Out:
# <Axes: xlabel='Product line'>

# %% [markdown]
# #### Display daily sales by day of the week

# %%
dw_mapping = {
    0:"Mon",
    1:"Tue",
    2:"Wed",
    3:"Thur",
    4:"Fri",
    5:"Sat",
    6:"Sun"
}

# %%
data["day_of_week"] = data["Date"].dt.dayofweek.map(dw_mapping)

# %%
(data["day_of_week"].value_counts()).plot(kind = "bar")
# Out:
# <Axes: xlabel='day_of_week'>

# %% [markdown]
# #### What will be the highest months for sales

# %%
month_mapping = {
    1:"Jan",
    2:"Feb",
    3:"March"
}

# %%
data["month"] = data["Date"].dt.month.map(month_mapping)

# %%
sns.barplot(data["month"].value_counts())
# Out:
# <Axes: xlabel='month', ylabel='count'>
