# %% [markdown]
# # Udemy Courses Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### import data

# %%
data = pd.read_csv("C:\\Users\\hp\\Downloads\\udemy_courses.csv",parse_dates=["published_timestamp"])
data
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %%
data.tail()
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# #### shape

# %%
print("No. of rows = ",data.shape[0])
print("No. of columns = ",data.shape[1])
# Out:
# No. of rows =  3678
# No. of columns =  12

# %% [markdown]
# #### Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %% [markdown]
# #### Null values

# %%
print("Any missing values?",data.isnull().values.any())
# Out:
# Any missing values? False

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# #### Duplicate data

# %%
print("Total duplicate values = ",data.duplicated().sum())
# Out:
# Total duplicate values =  6

# %%
data = data.drop_duplicates()

# %%
data.duplicated().any()
# Out:
# False

# %% [markdown]
# #### Courses per subject

# %%
data["subject"].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
a = sns.countplot(x = "subject",data = data,width = 0.8,hue = "subject",palette="dark")
plt.xlabel("Subjects",fontsize = 11)
plt.ylabel("Number of courses per subject",fontsize = 11)
plt.xticks(rotation = 30)
for x in a.containers:
    a.bar_label(x)
plt.show()

# %% [markdown]
# #### Levels for which Udemy provide courses

# %%
data["level"].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
a = sns.countplot(x = data["level"],hue = width = 0.8,palette="dark")
plt.xlabel("Level",fontsize = 11)
plt.ylabel("Number of courses per level",fontsize = 11)
plt.xticks(rotation = 30)
for x in a.containers:
    a.bar_label(x)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11320\810671542.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   a = sns.countplot(x = data["level"],width = 0.8,palette="dark")

# %% [markdown]
# #### Count of Paid and Free Courses

# %%
data["is_paid"].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %%
y = sns.countplot(x = "is_paid",data = data,width = 0.4)
for x in y.containers:
    y.bar_label(x)

# %% [markdown]
# #### Course having more lectures(free or paid)

# %%
data.groupby("is_paid")["num_lectures"].mean()
# Out:
# is_paid
# False    21.416129
# True     41.866746
# Name: num_lectures, dtype: float64

# %% [markdown]
# #### Courses having higher number of Subscribers

# %%
b = sns.barplot(x = "is_paid",y = "num_subscribers",data = data,errorbar = None )
for x in b.containers:
    b.bar_label(x)

# %% [markdown]
# #### Courses having highest Subscribers

# %%
data.groupby("level")["num_subscribers"].mean()
# Out:
# level
# All Levels            3569.761558
# Beginner Level        3195.459779
# Expert Level           865.448276
# Intermediate Level    1762.482185
# Name: num_subscribers, dtype: float64

# %%
y = sns.barplot(x = "level",y = "num_subscribers",data = data,hue = "is_paid",errorbar = None)
for x in y.containers:
    y.bar_label(x)

# %% [markdown]
# #### Most popular course title

# %%
data[data["num_subscribers"].max() == data["num_subscribers"]]["course_title"]
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %%
data[data["num_subscribers"].mean() == data["num_subscribers"]]["course_title"].head(10)
# Out:
# Series([], Name: course_title, dtype: object)

# %%
top_10 = data.sort_values(by = "num_subscribers",ascending = False).head(10)

# %%
sns.barplot(x = "num_subscribers",y = "course_title",hue = "course_title",data = top_10,legend = False)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# #### Course having highest number of reviews

# %%
z = data.sort_values(by = "num_reviews",ascending = False)

# %%
plt.figure(figsize = (10,4))
sns.barplot(x = "subject",y = "num_reviews",hue = "subject",data = z)
# Out:
# <Axes: xlabel='subject', ylabel='num_reviews'>

# %% [markdown]
# #### Does price affect number of reviews

# %%
plt.figure(figsize = (13,6))
sns.scatterplot(x = "price",y = "num_reviews",data = data)
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %% [markdown]
# #### Number of courses related to python

# %%
len(data[data["course_title"].str.contains("python",case = False)])
# Out:
# 29

# %% [markdown]
# #### 10 most popular python courses as per number of subscribers

# %%
a = data[data["course_title"].str.contains("python",case = False)].sort_values(by = "num_subscribers",ascending = False).head(10)

# %%
plt.figure(figsize = (13,6))
sns.barplot(y = "course_title",x = "num_subscribers",hue = "num_subscribers",palette="dark",data = a,orient = "h")
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# #### Year in which highest number of courses were posted

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data["year"] = data["published_timestamp"].dt.year
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11320\2757554554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["year"] = data["published_timestamp"].dt.year

# %%
sns.countplot(x = "year",hue = "year",data = data,legend = False)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# #### Category wise count of Posted subjects(year wise)

# %%
data.groupby("year")["subject"].value_counts()
# Out:
# year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       223
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64
